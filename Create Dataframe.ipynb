# %% [markdown]
# ## Data Mahasiswa

# %%
import pandas as pd
data = {
    "Nama" : ["Andi","Budi","Citra","Dina"],
    "Umur" : [20,21,19,22],
    "Jurusan" : ["Informatika","Teknik","Akutansi","Hukum"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Nama  Umur      Jurusan
# 0   Andi    20  Informatika
# 1   Budi    21       Teknik
# 2  Citra    19     Akutansi
# 3   Dina    22        Hukum

# %% [markdown]
# ## Latihan 2 - Data Produk

# %%
import pandas as pd
produk = {
    "Barang" : ["Mouse","Keyboard","Monitor","Printer"],
    "Harga" : [150000,250000,1800000,2200000],
    "Stok" : [25,18,6,4]
}

df = pd.DataFrame(produk)
print(df)
# Out:
#      Barang    Harga  Stok
# 0     Mouse   150000    25
# 1  Keyboard   250000    18
# 2   Monitor  1800000     6
# 3   Printer  2200000     4

# %% [markdown]
# ## Latihan 3 - Data Karyawan

# %%
import pandas as pd
karyawan = {
    "Nama" : ["Rina","Yoga","Sinta","Fajar"],
    "Divisi" : ["HR","IT","Finance","Marketing"],
    "Gaji" : [5000000,7000000,6500000,5500000]
}

df = pd.DataFrame(karyawan)
print(df)
# Out:
#     Nama     Divisi     Gaji
# 0   Rina         HR  5000000
# 1   Yoga         IT  7000000
# 2  Sinta    Finance  6500000
# 3  Fajar  Marketing  5500000

# %% [markdown]
# ## Latihan 4 - Data Penjualan

# %%
import pandas as pd
penjualan = {
    "Produk" : ["Laptop","HP","Tablet","Smartwatch"],
    "Jumlah" : [10,20,15,8],
    "Pendapatan" : [80000000,50000000,45000000,12000000]
                
}
df = pd.DataFrame(penjualan)
print(df)
# Out:
#        Produk  Jumlah  Pendapatan
# 0      Laptop      10    80000000
# 1          HP      20    50000000
# 2      Tablet      15    45000000
# 3  Smartwatch       8    12000000

# %% [markdown]
# ## Latihan 5

# %%
import pandas as pd
buku = {
    "Judul" : ["Python","SQL","Excel","Power BI"],
    "Penulis" : ["A","B","C","D"],
    "Harga" : [120000,100000,90000,150000]
}
df = pd.DataFrame(buku)
print(df)
# Out:
#       Judul Penulis   Harga
# 0    Python       A  120000
# 1       SQL       B  100000
# 2     Excel       C   90000
# 3  Power BI       D  150000

# %% [markdown]
# ## Latihan 6 - Data Kendaraan

# %%
import pandas as pd
kendaraan = {
    "Merek" : ["Toyota","Honda","Suzuki","Mitsubishi"],
    "Tahun" : [2020,2022,2019,2021],
    "Warna" : ["Hitam","Putih","Merah","Abu-abu"]
}

df = pd.DataFrame(kendaraan)
print(df)
# Out:
#         Merek  Tahun    Warna
# 0      Toyota   2020    Hitam
# 1       Honda   2022    Putih
# 2      Suzuki   2019    Merah
# 3  Mitsubishi   2021  Abu-abu

# %% [markdown]
# ## Latihan 7 - Data Film

# %%
import pandas as pd
film = {
    "Judul" : ["Avengers","Titanic","Avatar","Joker"],
    "Genre" : ["Action","Drama","Sci-Fi","Crime"],
    "Rating" : [8.8, 7.9, 8.1, 8.4]
}

df = pd.DataFrame(film)
print(df)
# Out:
#       Judul   Genre  Rating
# 0  Avengers  Action     8.8
# 1   Titanic   Drama     7.9
# 2    Avatar  Sci-Fi     8.1
# 3     Joker   Crime     8.4

# %% [markdown]
# ## Latihan 8 - Data Nilai Siswa

# %%
import pandas as pd
nilai = {
    "Nama" : ["Ali","Bella","Cici","Doni"],
    "Matematika" : [85,90,78,88],
    "Bahasa" : [80,92,84,89]
}

df=pd.DataFrame(nilai)

print(df)
# Out:
#     Nama  Matematika  Bahasa
# 0    Ali          85      80
# 1  Bella          90      92
# 2   Cici          78      84
# 3   Doni          88      89

# %% [markdown]
# ## latihan 9 - Data Smartphone

# %%
import pandas as pd
smartphone = {
    "Merk" : ["Samsung","Xiaomi","Oppo","Vivo"],
    "RAM (Gb)" : [8,12,8,6],
    "Harga (Rp)" : [4500000,3800000,4200000,3500000],
}

df=pd.DataFrame(smartphone)
print(df)
# Out:
#       Merk  RAM (Gb)  Harga (Rp)
# 0  Samsung         8     4500000
# 1   Xiaomi        12     3800000
# 2     Oppo         8     4200000
# 3     Vivo         6     3500000

# %% [markdown]
# ## Latihan 10 - Data Makanan

# %%
import pandas as pd
makanan = {
    "Menu" : ["Nasi Goreng","Bakso","Sate","Mie Ayam"],
    "Harga" : [18000,20000,25000,17000],
    "Terjual" : [40,35,25,50]
}
df = pd.DataFrame(makanan)
print(df)
# Out:
#           Menu  Harga  Terjual
# 0  Nasi Goreng  18000       40
# 1        Bakso  20000       35
# 2         Sate  25000       25
# 3     Mie Ayam  17000       50
